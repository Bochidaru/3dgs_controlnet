# %%
from torch.utils.data import DataLoader
from tutorial_dataset import MyDataset
from ldm.modules.encoders.modules import FrozenDFN2BImageEmbedder
import torch

dataset = MyDataset(isTest=False)
dataloader = DataLoader(dataset, num_workers=0, batch_size=1, shuffle=True)
print(len(dataloader))
batch = next(iter(dataloader))
ref1_batch = batch["ref1"].permute(0, 3, 1, 2)
# Out:
# 115

# %%
clip_model = FrozenDFN2BImageEmbedder()
result = clip_model.encode(ref1_batch)

# %%
result
# Out:
# tensor([[[-0.0201,  0.0141, -0.0278,  ...,  0.0318,  0.0191,  0.0276],
#          [-0.0105,  0.0235, -0.0406,  ...,  0.0213,  0.0506, -0.0077],
#          [-0.0300, -0.0030, -0.0292,  ...,  0.0241,  0.0153,  0.0046],
#          ...,
#          [-0.0192, -0.0009, -0.0111,  ...,  0.0359,  0.0160, -0.0113],
#          [-0.0097,  0.0127, -0.0315,  ...,  0.0095,  0.0461, -0.0065],
#          [-0.0137,  0.0196, -0.0402,  ...,  0.0223,  0.0462, -0.0026]]],
#        device='cuda:0')

# %%
print(type(ref1_batch))
print(ref1_batch.shape)
print(ref1_batch.dtype)
# Out:
# <class 'torch.Tensor'>
# torch.Size([1, 3, 512, 512])
# torch.float32
